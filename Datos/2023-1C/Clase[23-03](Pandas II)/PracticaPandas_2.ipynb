# %%
import pandas as pd

# %%
df = pd.read_csv("anime.csv")

# %% [markdown]
# Revisemos nuevamente las columnas de nuestro dataframe

# %%
df.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#        'Type', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
#        'Studios', 'Source', 'Duration', 'Rating', 'Ranked', 'Popularity',
#        'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped',
#        'Plan to Watch', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
#        'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1'],
#       dtype='object')

# %% [markdown]
# Mi objetivo es contar la cantidad de series diferentes que hay asociadas a cada genero de anime. Con eso en mente, hay columnas que bien podria omitir, tanto por simplicidad para leer como para operar:

# %%
df_original = df
df = df[["MAL_ID","Name","Genres"]]

df
# Out:
#        MAL_ID                             Name  \
# 0           1                     Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira
# 2           6                           Trigun
# 3           7               Witch Hunter Robin
# 4           8                   Bouken Ou Beet
# ...       ...                              ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu
# 17558   48483                     Mieruko-chan
# 17559   48488  Higurashi no Naku Koro ni Sotsu
# 17560   48491      Yama no Susume: Next Summit
# 17561   48492                    Scarlet Nexus
#
#                                                   Genres
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...                                                  ...
# 17557                   Adventure, Mystery, Supernatural
# 17558                       Comedy, Horror, Supernatural
# 17559  Mystery, Dementia, Horror, Psychological, Supe...
# 17560                   Adventure, Slice of Life, Comedy
# 17561                                    Action, Fantasy
#
# [17562 rows x 3 columns]

# %% [markdown]
# Por ahora no me interesa ni sirve mucha mas informacion, pero por las dudas me guardo el dataframe original para despues. En este caso simplemente podria volver a leerlo, en otros casos, puede que tenga que volver a procesarlo todo. Es en el segundo caso donde nos puede servir trabajar sobre con una copia, al utilizar el operador `[]` estamos **copiando** eñ dataframe en uno nuevo con unicamente los datos que pertenezcan al filtro (ya sean filas o columnas).

# %% [markdown]
# # Transformando los generos
#
# Para poder separar los generos de cada serie, necesito primero pasar la cadena a una lista. Entremedio, proceso los generos para eliminar los espacios a los costados y las mayusculas, para evitar que un genero se separe en multiples.
#
# Podemos hacer todo esto con un map y una funcion lambda como la vez pasada:

# %%
df.Genres.map(lambda x: [ y.strip().lower() for y in x.split(",")])
# Out:
# 0        [action, adventure, comedy, drama, sci-fi, space]
# 1                  [action, drama, mystery, sci-fi, space]
# 2        [action, sci-fi, adventure, comedy, drama, sho...
# 3        [action, mystery, police, supernatural, drama,...
# 4              [adventure, fantasy, shounen, supernatural]
#                                ...
# 17557                   [adventure, mystery, supernatural]
# 17558                       [comedy, horror, supernatural]
# 17559    [mystery, dementia, horror, psychological, sup...
# 17560                   [adventure, slice of life, comedy]
# 17561                                    [action, fantasy]
# Name: Genres, Length: 17562, dtype: object

# %% [markdown]
# El resultado de aplicarle `.map` a una serie, es otra serie. En este caso la serie es una serie de 'objects' porque es una columna de listas.
#
# En este caso, vamos a crear una nueva columna en nuestro dataframe con los datos de la serie creada. En este caso hacemos una nueva columna para tener como referencia los datos originales, pero bien se podria sobreescribir la columna original para optimizar el uso de espacio. Siempre que se vaya a agregar una columna hay que utilizar `[]` (se puede utilizar `.` pero esta fuertemente desaconsejado).

# %%
df["generos"] = df.Genres.map(lambda x: [ y.strip().lower() for y in x.split(",")])
df.head(20)
# Out:
# <ipython-input-9-1d6bb2f2dbd4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["generos"] = df.Genres.map(lambda x: [ y.strip().lower() for y in x.split(",")])
#     MAL_ID                             Name  \
# 0        1                     Cowboy Bebop
# 1        5  Cowboy Bebop: Tengoku no Tobira
# 2        6                           Trigun
# 3        7               Witch Hunter Robin
# 4        8                   Bouken Ou Beet
# 5       15                     Eyeshield 21
# 6       16             Hachimitsu to Clover
# 7       17       Hungry Heart: Wild Striker
# 8       18           Initial D Fourth Stage
# 9       19                          Monster
# 10      20                           Naruto
# 11      21                        One Piece
# 12      22              Tennis no Ouji-sama
# 13      23                 Ring ni Kakero 1
# 14      24                    School Rumble
# 15      25                        Sunabouzu
# 16      26                       Texhnolyze
# 17      27                    Trinity Blood
# 18      28                 Yakitate!! Japan
# 19      29                           Zipang
#
#                                                Genres  \
# 0     Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1               Action, Drama, Mystery, Sci-Fi, Space
# 2   Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3   Action, Mystery, Police, Supernatural, Drama, ...
# 4           Adventure, Fantasy, Shounen, Supernatural
# 5                     Action, Sports, Comedy, Shounen
# 6        Comedy, Drama, Josei, Romance, Slice of Life
# 7              Slice of Life, Comedy, Sports, Shounen
# 8                 Action, Cars, Sports, Drama, Seinen
# 9   Drama, Horror, Mystery, Police, Psychological,...
# 10  Action, Adventure, Comedy, Super Power, Martia...
# 11  Action, Adventure, Comedy, Super Power, Drama,...
# 12            Action, Comedy, Sports, School, Shounen
# 13                            Action, Shounen, Sports
# 14                   Comedy, Romance, School, Shounen
# 15  Action, Adventure, Comedy, Ecchi, Sci-Fi, Shounen
# 16               Action, Sci-Fi, Psychological, Drama
# 17                      Action, Supernatural, Vampire
# 18                                    Comedy, Shounen
# 19  Action, Military, Sci-Fi, Historical, Drama, S...
#
#                                               generos
# 0   [action, adventure, comedy, drama, sci-fi, space]
# 1             [action, drama, mystery, sci-fi, space]
# 2   [action, sci-fi, adventure, comedy, drama, sho...
# 3   [action, mystery, police, supernatural, drama,...
# 4         [adventure, fantasy, shounen, supernatural]
# 5                   [action, sports, comedy, shounen]
# 6      [comedy, drama, josei, romance, slice of life]
# 7            [slice of life, comedy, sports, shounen]
# 8               [action, cars, sports, drama, seinen]
# 9   [drama, horror, mystery, police, psychological...
# 10  [action, adventure, comedy, super power, marti...
# 11  [action, adventure, comedy, super power, drama...
# 12          [action, comedy, sports, school, shounen]
# 13                          [action, shounen, sports]
# 14                 [comedy, romance, school, shounen]
# 15  [action, adventure, comedy, ecchi, sci-fi, sho...
# 16             [action, sci-fi, psychological, drama]
# 17                    [action, supernatural, vampire]
# 18                                  [comedy, shounen]
# 19  [action, military, sci-fi, historical, drama, ...

# %% [markdown]
# Con los datos en una lista, ahora puedo aplicar `explode` para que cada valor se vuelva una fila y se una a los datos anteriores

# %%
expandido = df.explode("generos")
expandido
# Out:
#        MAL_ID                         Name  \
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# ...       ...                          ...
# 17560   48491  Yama no Susume: Next Summit
# 17560   48491  Yama no Susume: Next Summit
# 17560   48491  Yama no Susume: Next Summit
# 17561   48492                Scarlet Nexus
# 17561   48492                Scarlet Nexus
#
#                                                 Genres        generos
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space         action
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space      adventure
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space         comedy
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space          drama
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space         sci-fi
# ...                                                ...            ...
# 17560                 Adventure, Slice of Life, Comedy      adventure
# 17560                 Adventure, Slice of Life, Comedy  slice of life
# 17560                 Adventure, Slice of Life, Comedy         comedy
# 17561                                  Action, Fantasy         action
# 17561                                  Action, Fantasy        fantasy
#
# [50261 rows x 4 columns]

# %% [markdown]
# Notar que **School Rumble** esta asociado a 4 generos distintos, por ende ahora en nuestro nuevo DataFrame, va a aparecer 4 veces, cada una asociada a uno de los generos que le corresponde en la columna "genero".
#
# Ya que dejamos los nombres, podemos utilizarlos para indexar nuestro dataframe y asi poder revisar datos que conozcamos mas facilmente con `loc`

# %%
expandido.set_index("Name").loc["School Rumble"]
# Out:
#                MAL_ID                            Genres  generos
# Name
# School Rumble      24  Comedy, Romance, School, Shounen   comedy
# School Rumble      24  Comedy, Romance, School, Shounen  romance
# School Rumble      24  Comedy, Romance, School, Shounen   school
# School Rumble      24  Comedy, Romance, School, Shounen  shounen

# %% [markdown]
# Nota: como solo lo voy a utilizar una vez, lo dejo asi, pero puede serme util ya guardarme el dataframe con el nuevo indice.
#
# Igual que antes, normalizo los nombres pasandolos todos a minusculas para evitar que haya alguna clase de problema a futuro

# %%
expandido["name"] = expandido.Name.map(lambda x:x.lower())
expandido.head(20)
# Out:
#    MAL_ID                             Name  \
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 3       7               Witch Hunter Robin
# 3       7               Witch Hunter Robin
# 3       7               Witch Hunter Robin
#
#                                               Genres    generos  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     action
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space  adventure
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     comedy
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space      drama
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     sci-fi
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space      space
# 1              Action, Drama, Mystery, Sci-Fi, Space     action
# 1              Action, Drama, Mystery, Sci-Fi, Space      drama
# 1              Action, Drama, Mystery, Sci-Fi, Space    mystery
# 1              Action, Drama, Mystery, Sci-Fi, Space     sci-fi
# 1              Action, Drama, Mystery, Sci-Fi, Space      space
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     action
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     sci-fi
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen  adventure
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     comedy
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen      drama
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen    shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...     action
# 3  Action, Mystery, Police, Supernatural, Drama, ...    mystery
# 3  Action, Mystery, Police, Supernatural, Drama, ...     police
#
#                               name
# 0                     cowboy bebop
# 0                     cowboy bebop
# 0                     cowboy bebop
# 0                     cowboy bebop
# 0                     cowboy bebop
# 0                     cowboy bebop
# 1  cowboy bebop: tengoku no tobira
# 1  cowboy bebop: tengoku no tobira
# 1  cowboy bebop: tengoku no tobira
# 1  cowboy bebop: tengoku no tobira
# 1  cowboy bebop: tengoku no tobira
# 2                           trigun
# 2                           trigun
# 2                           trigun
# 2                           trigun
# 2                           trigun
# 2                           trigun
# 3               witch hunter robin
# 3               witch hunter robin
# 3               witch hunter robin

# %% [markdown]
# # Pivots

# %% [markdown]
# ❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗
#
# Nota al lector: _Podria hacer un groupby generos y despues hacer un count unique para obtener el resultado que buscaba originalmente... pero no porque sino aca terminaria el notebook y no quiero buscar otro dataset con las propiedades de este, asi que seguime la corriente. Siempre podes como ejercicio cargar en un notebook nuevo el dataset e intentar llegar al resultado por ese camino._
# ❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗
#
#
# Podria servirme, tener una matiz con para cada serie, si es o no de determinado genero, esto me dejaria utilizando un loc, obtener facilmente esa informacion.
#
# Para eso vamos a utilizar pivot porque cada serie solo deberia aparecer una unica vez asociada a un genero. Elegimos la columna de MAL_ID como valores porque en este caso es lo mismo, o tiene un valor (la serie es de ese genero) o es un nan (la serie no es de ese genero)

# %%
expandido.pivot("name","generos","MAL_ID")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f3adba5afecd> in <module>
# ----> 1 expandido.pivot("name","generos","MAL_ID")
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7883         from pandas.core.reshape.pivot import pivot
#    7884
# -> 7885         return pivot(self, index=index, columns=columns, values=values)
#    7886
#    7887     _shared_docs[
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     518         else:
#     519             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520     return indexed.unstack(columns_listlike)
#     521
#     522
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    4155         from pandas.core.reshape.reshape import unstack
#    4156
# -> 4157         return unstack(self, level, fill_value)
#    4158
#    4159     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     489         if is_1d_only_ea_dtype(obj.dtype):
#     490             return _unstack_extension_series(obj, level, fill_value)
# --> 491         unstacker = _Unstacker(
#     492             obj.index, level=level, constructor=obj._constructor_expanddim
#     493         )
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     138             )
#     139
# --> 140         self._make_selectors()
#     141
#     142     @cache_readonly
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     190
#     191         if mask.sum() < len(self.index):
# --> 192             raise ValueError("Index contains duplicate entries, cannot reshape")
#     193
#     194         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# Pivot falla porque dice tener valores repetidos. Esto significa que existe **al menos** un par `nombre,genero` que aparece mas de una vez. Por precondicion no deberia ocurrir, porque las series no deberian repetirse y los generos que extrajimos son unicos. Este tipo de cosas nos hablan de que hay errores en el dataset (y nos demuestran que no se puede confiar ciegamente en nada, repito, **SIEMPRE HAY QUE REVISAR LOS DATOS, ES PARTE FUNDAMENTAL DEL PROCESO**
#
#
#
# Si hubieramos utilizado pivot table, esto no hubiera ocurrido porque por defecto va a intentar promediar los valores (y al ser el id un numero entero) y no iba a fallar.
#
# Probamos entonces utilizando pivot table, pero utilizando como funcion de agregacion count para contar los elementos y asi encontrar los pares series-genero que se repiten (sino no hubiera fallado pivot para empezar).

# %%
df_count = expandido.pivot_table(index="name",columns="generos",values="MAL_ID",aggfunc="count")
df_count
# Out:
# generos                                             action  adventure  cars  \
# name
# "0"                                                    NaN        NaN   NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...     NaN        NaN   NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi              NaN        NaN   NaN
# "bungaku shoujo" memoire                               NaN        NaN   NaN
# "bungaku shoujo" movie                                 NaN        NaN   NaN
# ...                                                    ...        ...   ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...     NaN        NaN   NaN
# zutto suki datta                                       NaN        NaN   NaN
# üks uks                                                NaN        NaN   NaN
# ēldlive                                                1.0        NaN   NaN
# ◯                                                      NaN        NaN   NaN
#
# generos                                             comedy  dementia  demons  \
# name
# "0"                                                    NaN       NaN     NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...     NaN       NaN     NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi              1.0       NaN     NaN
# "bungaku shoujo" memoire                               NaN       NaN     NaN
# "bungaku shoujo" movie                                 NaN       NaN     NaN
# ...                                                    ...       ...     ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...     NaN       NaN     NaN
# zutto suki datta                                       NaN       NaN     NaN
# üks uks                                                NaN       1.0     NaN
# ēldlive                                                NaN       NaN     NaN
# ◯                                                      NaN       1.0     NaN
#
# generos                                             drama  ecchi  fantasy  \
# name
# "0"                                                   NaN    NaN      NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...    NaN    NaN      NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi             NaN    NaN      1.0
# "bungaku shoujo" memoire                              1.0    NaN      NaN
# "bungaku shoujo" movie                                1.0    NaN      NaN
# ...                                                   ...    ...      ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...    NaN    NaN      NaN
# zutto suki datta                                      1.0    NaN      NaN
# üks uks                                               NaN    NaN      NaN
# ēldlive                                               NaN    NaN      NaN
# ◯                                                     NaN    NaN      NaN
#
# generos                                             game  ...  slice of life  \
# name                                                      ...
# "0"                                                  NaN  ...            NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...   NaN  ...            NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi            NaN  ...            NaN
# "bungaku shoujo" memoire                             NaN  ...            NaN
# "bungaku shoujo" movie                               NaN  ...            NaN
# ...                                                  ...  ...            ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...   NaN  ...            NaN
# zutto suki datta                                     NaN  ...            NaN
# üks uks                                              NaN  ...            NaN
# ēldlive                                              NaN  ...            NaN
# ◯                                                    NaN  ...            NaN
#
# generos                                             space  sports  \
# name
# "0"                                                   NaN     NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...    NaN     NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi             NaN     NaN
# "bungaku shoujo" memoire                              NaN     NaN
# "bungaku shoujo" movie                                NaN     NaN
# ...                                                   ...     ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...    NaN     NaN
# zutto suki datta                                      NaN     NaN
# üks uks                                               NaN     NaN
# ēldlive                                               1.0     NaN
# ◯                                                     NaN     NaN
#
# generos                                             super power  supernatural  \
# name
# "0"                                                         NaN           NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...          NaN           NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi                   NaN           NaN
# "bungaku shoujo" memoire                                    NaN           NaN
# "bungaku shoujo" movie                                      NaN           NaN
# ...                                                         ...           ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...          NaN           NaN
# zutto suki datta                                            NaN           NaN
# üks uks                                                     NaN           NaN
# ēldlive                                                     NaN           NaN
# ◯                                                           NaN           NaN
#
# generos                                             thriller  unknown  \
# name
# "0"                                                      NaN      NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...       NaN      NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi                NaN      NaN
# "bungaku shoujo" memoire                                 NaN      NaN
# "bungaku shoujo" movie                                   NaN      NaN
# ...                                                      ...      ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...       NaN      NaN
# zutto suki datta                                         NaN      NaN
# üks uks                                                  NaN      NaN
# ēldlive                                                  NaN      NaN
# ◯                                                        NaN      NaN
#
# generos                                             vampire  yaoi  yuri
# name
# "0"                                                     NaN   NaN   NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...      NaN   NaN   NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi               NaN   NaN   NaN
# "bungaku shoujo" memoire                                NaN   NaN   NaN
# "bungaku shoujo" movie                                  NaN   NaN   NaN
# ...                                                     ...   ...   ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...      NaN   NaN   NaN
# zutto suki datta                                        NaN   NaN   NaN
# üks uks                                                 NaN   NaN   NaN
# ēldlive                                                 NaN   NaN   NaN
# ◯                                                       NaN   NaN   NaN
#
# [17558 rows x 44 columns]

# %% [markdown]
# Este dataframe nuevo, ahora tiene 1 si la serie esta asociada a un genero, o NaN en caso contrario. O eso seria lo esperable, pero ya sabemos de antemano que hay almenos algo que no e ni nan ni 1. Podemos probar obteniendo el maximo por columna:

# %%
df_count.max()
# Out:
# generos
# action           2.0
# adventure        1.0
# cars             1.0
# comedy           1.0
# dementia         1.0
# demons           2.0
# drama            1.0
# ecchi            1.0
# fantasy          3.0
# game             1.0
# harem            1.0
# hentai           1.0
# historical       1.0
# horror           1.0
# josei            1.0
# kids             2.0
# magic            3.0
# martial arts     1.0
# mecha            1.0
# military         1.0
# music            1.0
# mystery          1.0
# parody           1.0
# police           1.0
# psychological    1.0
# romance          1.0
# samurai          1.0
# school           3.0
# sci-fi           1.0
# seinen           1.0
# shoujo           1.0
# shoujo ai        1.0
# shounen          1.0
# shounen ai       1.0
# slice of life    1.0
# space            1.0
# sports           1.0
# super power      1.0
# supernatural     1.0
# thriller         1.0
# unknown          1.0
# vampire          1.0
# yaoi             1.0
# yuri             1.0
# dtype: float64

# %% [markdown]
# Vemos que por ejemplo 'magic', tiene al menos una serie asociada 3 veces. Usemos un loc para buscar esos valores, porque a diferencia de los filtros que usabamos antes, con loc no voy a estar generando un nuevo dataframe:

# %%
df_count.loc[df_count["magic"] > 1]
# Out:
# generos                                             action  adventure  cars  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...     2.0        NaN   NaN
#
# generos                                             comedy  dementia  demons  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...     NaN       NaN     2.0
#
# generos                                             drama  ecchi  fantasy  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...    NaN    NaN      3.0
#
# generos                                             game  ...  slice of life  \
# name                                                      ...
# maou gakuin no futekigousha: shijou saikyou no ...   NaN  ...            NaN
#
# generos                                             space  sports  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...    NaN     NaN
#
# generos                                             super power  supernatural  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...          NaN           NaN
#
# generos                                             thriller  unknown  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...       NaN      NaN
#
# generos                                             vampire  yaoi  yuri
# name
# maou gakuin no futekigousha: shijou saikyou no ...      NaN   NaN   NaN
#
# [1 rows x 44 columns]

# %% [markdown]
# Si revisamos en el expandido, vemos que la serie aparece multiples veces, pero algunos de esos datos son inconsistentes. Esto nos puede llevar a pensar que el dataset esta mal, ya que no podemos con la informacion que tenemos saber el por que de los datos duplicados
#
# Notar que si no me hubiera querido ahorrar un paso unos frames mas arriba, ahora no tendria que volver a setear el indice.

# %%
expandido.set_index("name").loc["maou gakuin no futekigousha: shijou saikyou no maou no shiso, tensei shite shison-tachi no gakkou e"]
# Out:
#                                                     MAL_ID  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...   40496
# maou gakuin no futekigousha: shijou saikyou no ...   40496
# maou gakuin no futekigousha: shijou saikyou no ...   40496
# maou gakuin no futekigousha: shijou saikyou no ...   40496
# maou gakuin no futekigousha: shijou saikyou no ...   40496
# maou gakuin no futekigousha: shijou saikyou no ...   48417
# maou gakuin no futekigousha: shijou saikyou no ...   48417
# maou gakuin no futekigousha: shijou saikyou no ...   48417
# maou gakuin no futekigousha: shijou saikyou no ...   48418
# maou gakuin no futekigousha: shijou saikyou no ...   48418
# maou gakuin no futekigousha: shijou saikyou no ...   48418
# maou gakuin no futekigousha: shijou saikyou no ...   48418
# maou gakuin no futekigousha: shijou saikyou no ...   48418
#
#                                                                                                  Name  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# maou gakuin no futekigousha: shijou saikyou no ...  Maou Gakuin no Futekigousha: Shijou Saikyou no...
#
#                                                                                     Genres  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...                  Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...                  Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...                  Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
# maou gakuin no futekigousha: shijou saikyou no ...  Action, Demons, Magic, Fantasy, School
#
#                                                     generos
# name
# maou gakuin no futekigousha: shijou saikyou no ...   action
# maou gakuin no futekigousha: shijou saikyou no ...   demons
# maou gakuin no futekigousha: shijou saikyou no ...    magic
# maou gakuin no futekigousha: shijou saikyou no ...  fantasy
# maou gakuin no futekigousha: shijou saikyou no ...   school
# maou gakuin no futekigousha: shijou saikyou no ...    magic
# maou gakuin no futekigousha: shijou saikyou no ...  fantasy
# maou gakuin no futekigousha: shijou saikyou no ...   school
# maou gakuin no futekigousha: shijou saikyou no ...   action
# maou gakuin no futekigousha: shijou saikyou no ...   demons
# maou gakuin no futekigousha: shijou saikyou no ...    magic
# maou gakuin no futekigousha: shijou saikyou no ...  fantasy
# maou gakuin no futekigousha: shijou saikyou no ...   school

# %% [markdown]
# Con esto, sabemos que tenemos que buscar las series que aparecen mas de una vez, pero para ello deberiamos agrupar y despues aplicar un count.

# %%
df.groupby("Name").agg({"MAL_ID":"count"})
# Out:
#                                                     MAL_ID
# Name
# "0"                                                      1
# "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokuba...       1
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                1
# "Bungaku Shoujo" Memoire                                 1
# "Bungaku Shoujo" Movie                                   1
# ...                                                    ...
# xxxHOLiC Rou                                             1
# xxxHOLiC Shunmuki                                        1
# Üks Uks                                                  1
# ēlDLIVE                                                  1
# ◯                                                        1
#
# [17558 rows x 1 columns]

# %% [markdown]
# No tiene mucho sentido hacer un segundo df con los counts para unirlo a los datos originales, entonces es mejor utilizar transform que ya nos genera los datos para incluir en el DataFrame utilizando la informacion que almacena el objeto Group

# %%
df["apariciones"] = df.groupby("Name").transform("count")["MAL_ID"]
# Out:
# <ipython-input-33-0cb11c885ffc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["apariciones"] = df.groupby("Name").transform("count")["MAL_ID"]

# %% [markdown]
# Fijense que ya aca pandas nos da un warning. En este caso, estamos agregando una columna a df, pero df es una copia de `df_original` con menos columnas. Lo que nos dice pandas es: _"estos datos ya los tenes, te hiciste una copia con un par de columnas solo para agregarle un par de datos, hacelo sobre el original y no generes mugre de mas"_. Hasta ahora no hice nada con la copia que justifique haberla hecho, entonces tiene sentido el warning.

# %% [markdown]
# Volviendo, si eliminamos todos los invalidos, ahora podemos volver a hacer lo que hicimos al principio para llegar a aplicar pivot. En este caso no tengo forma de saber por que estan mas de una vez, y como no se como subsanar eso, descarto esos datos.
#
# Aplicando la misma logica que antes, me hago una nueva columna con el valor que me diga si es un dato valido o no (hago una nueva columna, porque quiza mas adelante me sirve eso para otra cosa.

# %%
df["invalido"] = df.apariciones > 1
# Out:
# <ipython-input-34-407c246731c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["invalido"] = df.apariciones > 1

# %%
df = df[~df.invalido]

# %%
df["generos"] = df.Genres.map(lambda x: [ y.strip().lower() for y in x.split(",")])
expandido = df.explode("generos")
expandido["name"] = expandido.Name.map(lambda x:x.lower())
# Out:
# <ipython-input-44-e6d0aa979b31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["generos"] = df.Genres.map(lambda x: [ y.strip().lower() for y in x.split(",")])

# %% [markdown]
# Ahora si, antes de hacer el pivot vamos a pensar mejor que es lo que queremos obtener. Estamos buscando llegar a un DataFrame que para cada serie, tenga para cada uno de los generos si pertenece a ese o no. Como lo que vamos a querer que aparezca en mi nuevo DataFrame son valores booleanos, y sabiendo que en _expandido_ estan todos los pares serie-genero que son validos; puedo agregar una columna solo con True para que al generar el pivot me queden los valores True en los pares validos.
#
# De la misma forma, sabemos que si en _expandido_ no aparece un determinado par serie-genero, el mismo es implicitamente False, entonces al pivot le puedo hacer un fillna por ese valor

# %%
expandido["t"] = True
serie_genero = expandido.pivot("name","generos","t")
serie_genero = serie_genero.fillna(False)
serie_genero
# Out:
# generos                                             action  adventure   cars  \
# name
# "0"                                                  False      False  False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...   False      False  False
# "bungaku shoujo" kyou no oyatsu: hatsukoi            False      False  False
# "bungaku shoujo" memoire                             False      False  False
# "bungaku shoujo" movie                               False      False  False
# ...                                                    ...        ...    ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...   False      False  False
# zutto suki datta                                     False      False  False
# üks uks                                              False      False  False
# ēldlive                                               True      False  False
# ◯                                                    False      False  False
#
# generos                                             comedy  dementia  demons  \
# name
# "0"                                                  False     False   False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...   False     False   False
# "bungaku shoujo" kyou no oyatsu: hatsukoi             True     False   False
# "bungaku shoujo" memoire                             False     False   False
# "bungaku shoujo" movie                               False     False   False
# ...                                                    ...       ...     ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...   False     False   False
# zutto suki datta                                     False     False   False
# üks uks                                              False      True   False
# ēldlive                                              False     False   False
# ◯                                                    False      True   False
#
# generos                                             drama  ecchi  fantasy  \
# name
# "0"                                                 False  False    False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...  False  False    False
# "bungaku shoujo" kyou no oyatsu: hatsukoi           False  False     True
# "bungaku shoujo" memoire                             True  False    False
# "bungaku shoujo" movie                               True  False    False
# ...                                                   ...    ...      ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...  False  False    False
# zutto suki datta                                     True  False    False
# üks uks                                             False  False    False
# ēldlive                                             False  False    False
# ◯                                                   False  False    False
#
# generos                                              game  ...  slice of life  \
# name                                                       ...
# "0"                                                 False  ...          False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...  False  ...          False
# "bungaku shoujo" kyou no oyatsu: hatsukoi           False  ...          False
# "bungaku shoujo" memoire                            False  ...          False
# "bungaku shoujo" movie                              False  ...          False
# ...                                                   ...  ...            ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...  False  ...          False
# zutto suki datta                                    False  ...          False
# üks uks                                             False  ...          False
# ēldlive                                             False  ...          False
# ◯                                                   False  ...          False
#
# generos                                             space  sports  \
# name
# "0"                                                 False   False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...  False   False
# "bungaku shoujo" kyou no oyatsu: hatsukoi           False   False
# "bungaku shoujo" memoire                            False   False
# "bungaku shoujo" movie                              False   False
# ...                                                   ...     ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...  False   False
# zutto suki datta                                    False   False
# üks uks                                             False   False
# ēldlive                                              True   False
# ◯                                                   False   False
#
# generos                                             super power  supernatural  \
# name
# "0"                                                       False         False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...        False         False
# "bungaku shoujo" kyou no oyatsu: hatsukoi                 False         False
# "bungaku shoujo" memoire                                  False         False
# "bungaku shoujo" movie                                    False         False
# ...                                                         ...           ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...        False         False
# zutto suki datta                                          False         False
# üks uks                                                   False         False
# ēldlive                                                   False         False
# ◯                                                         False         False
#
# generos                                             thriller  unknown  \
# name
# "0"                                                    False    False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...     False    False
# "bungaku shoujo" kyou no oyatsu: hatsukoi              False    False
# "bungaku shoujo" memoire                               False    False
# "bungaku shoujo" movie                                 False    False
# ...                                                      ...      ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...     False    False
# zutto suki datta                                       False    False
# üks uks                                                False    False
# ēldlive                                                False    False
# ◯                                                      False    False
#
# generos                                             vampire   yaoi   yuri
# name
# "0"                                                   False  False  False
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...    False  False  False
# "bungaku shoujo" kyou no oyatsu: hatsukoi             False  False  False
# "bungaku shoujo" memoire                              False  False  False
# "bungaku shoujo" movie                                False  False  False
# ...                                                     ...    ...    ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...    False  False  False
# zutto suki datta                                      False  False  False
# üks uks                                               False  False  False
# ēldlive                                               False  False  False
# ◯                                                     False  False  False
#
# [17555 rows x 44 columns]

# %% [markdown]
# Con este formato puedo obtener facilmente para cualquier serie si pertenece a un determinado genero. Y como puedo hacer eso, puedo utilizarlo para filtrar los otros DataFrame

# %%
serie_genero.loc["ēldlive","game"]
# Out:
# False

# %% [markdown]
# Con este formato ahora me puedo hacer una funcion generica que utilizando loc, me devuelva si una serie es o no de un determinado genero

# %%
def es_tipo(serie,tipo):
    return serie_genero.loc[serie,tipo]

# %% [markdown]
# Y eso lo podemos utilizar sobre el dataframe original para obtener las series que son de un determinado tipo de forma mas eficiente que haciendo un in sobre la lista. El resultado al que llegamos, si bien paso por muchas transformaciones, si al final voy a filtrar muchas mas veces el dataframe original por algun genero especifico, es mas eficiente de esta forma

# %%
df_original.loc[ df_original.Name.map( lambda x: es_tipo(x.lower(),"game"))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hinamatsuri'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-060d2ab59cbd> in <module>
# ----> 1 df_original.loc[ df_original.Name.map( lambda x: es_tipo(x.lower(),"game"))]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4235         dtype: object
#    4236         """
# -> 4237         new_values = self._map_values(arg, na_action=na_action)
#    4238         return self._constructor(new_values, index=self.index).__finalize__(
#    4239             self, method="map"
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     878
#     879         # mapper is a function
# --> 880         new_values = map_f(values, mapper)
#     881
#     882         return new_values
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-54-060d2ab59cbd> in <lambda>(x)
# ----> 1 df_original.loc[ df_original.Name.map( lambda x: es_tipo(x.lower(),"game"))]
#
# <ipython-input-51-cec8736dd01a> in es_tipo(serie, tipo)
#       1 def es_tipo(serie,tipo):
# ----> 2     return serie_genero.loc[serie,tipo]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     958             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959             if self._is_scalar_access(key):
# --> 960                 return self.obj._get_value(*key, takeable=self._takeable)
#     961             return self._getitem_tuple(key)
#     962         else:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3620             #  results if our categories are integers that dont match our codes
#    3621             # IntervalIndex: IntervalTree has no get_loc
# -> 3622             row = self.index.get_loc(index)
#    3623             return series._values[row]
#    3624
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'hinamatsuri'

# %% [markdown]
# O bueno, podria si todos los datos estuvieran en el nuevo dataframe, pero sabemos que no porque limpie los que eran invalidos.
#
# Tarea para el lector: Como esto no funciona, hacer:
#
# * una funcion que intente obtener el valor del nuevo dataframe y sino que devuelva false (en caso de no existir)
#
# * despues de la proxima clase, agregar los datos de si es invalido combinando los dos dataframes, el original y el que tiene los datos de invalidos.
#
# * rehacer todo utilizando loc, para que el original tenga los datos de si es valido o invalido y poder hacer el filtrado anterior agregando que lo haga solo para los validos.

# %%
expandido.loc[ expandido.name.map( lambda x: es_tipo(x,"game"))]
# Out:
#        MAL_ID                                               Name  \
# 29         48                                        .hack//Sign
# 29         48                                        .hack//Sign
# 29         48                                        .hack//Sign
# 29         48                                        .hack//Sign
# 29         48                                        .hack//Sign
# ...       ...                                                ...
# 17477   46488  Tai-Ari deshita.: Ojou-sama wa Kakutou Game na...
# 17477   46488  Tai-Ari deshita.: Ojou-sama wa Kakutou Game na...
# 17535   48391                                       Mazica Party
# 17535   48391                                       Mazica Party
# 17535   48391                                       Mazica Party
#
#                                                  Genres  apariciones  \
# 29     Game, Sci-Fi, Adventure, Mystery, Magic, Fantasy            1
# 29     Game, Sci-Fi, Adventure, Mystery, Magic, Fantasy            1
# 29     Game, Sci-Fi, Adventure, Mystery, Magic, Fantasy            1
# 29     Game, Sci-Fi, Adventure, Mystery, Magic, Fantasy            1
# 29     Game, Sci-Fi, Adventure, Mystery, Magic, Fantasy            1
# ...                                                 ...          ...
# 17477           Game, Comedy, School, Seinen, Shoujo Ai            1
# 17477           Game, Comedy, School, Seinen, Shoujo Ai            1
# 17535                              Game, Magic, Fantasy            1
# 17535                              Game, Magic, Fantasy            1
# 17535                              Game, Magic, Fantasy            1
#
#        invalido    generos                                               name  \
# 29        False       game                                        .hack//sign
# 29        False     sci-fi                                        .hack//sign
# 29        False  adventure                                        .hack//sign
# 29        False    mystery                                        .hack//sign
# 29        False      magic                                        .hack//sign
# ...         ...        ...                                                ...
# 17477     False     seinen  tai-ari deshita.: ojou-sama wa kakutou game na...
# 17477     False  shoujo ai  tai-ari deshita.: ojou-sama wa kakutou game na...
# 17535     False       game                                       mazica party
# 17535     False      magic                                       mazica party
# 17535     False    fantasy                                       mazica party
#
#           t
# 29     True
# 29     True
# 29     True
# 29     True
# 29     True
# ...     ...
# 17477  True
# 17477  True
# 17535  True
# 17535  True
# 17535  True
#
# [1373 rows x 8 columns]

# %% [markdown]
# Quiza para un unico valor no tiene mucho sentido, pero este formato me permite hacer cosas un poco mas avanzadas como generarme una funcion que me devuelva si aparece alguno de los generos de una lista arbitraria

# %%
expandido
# Out:
#        MAL_ID                         Name  \
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# ...       ...                          ...
# 17560   48491  Yama no Susume: Next Summit
# 17560   48491  Yama no Susume: Next Summit
# 17560   48491  Yama no Susume: Next Summit
# 17561   48492                Scarlet Nexus
# 17561   48492                Scarlet Nexus
#
#                                                 Genres  apariciones  invalido  \
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space            1     False
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space            1     False
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space            1     False
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space            1     False
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space            1     False
# ...                                                ...          ...       ...
# 17560                 Adventure, Slice of Life, Comedy            1     False
# 17560                 Adventure, Slice of Life, Comedy            1     False
# 17560                 Adventure, Slice of Life, Comedy            1     False
# 17561                                  Action, Fantasy            1     False
# 17561                                  Action, Fantasy            1     False
#
#              generos                         name     t
# 0             action                 cowboy bebop  True
# 0          adventure                 cowboy bebop  True
# 0             comedy                 cowboy bebop  True
# 0              drama                 cowboy bebop  True
# 0             sci-fi                 cowboy bebop  True
# ...              ...                          ...   ...
# 17560      adventure  yama no susume: next summit  True
# 17560  slice of life  yama no susume: next summit  True
# 17560         comedy  yama no susume: next summit  True
# 17561         action                scarlet nexus  True
# 17561        fantasy                scarlet nexus  True
#
# [50239 rows x 8 columns]

# %%
df["name"] = df.Name.map(lambda x: x.strip().lower())
# Out:
# <ipython-input-108-e79c442958ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["name"] = df.Name.map(lambda x: x.strip().lower())

# %%
def tiene_generos(name,generos):  
    for genero in generos:
        if serie_genero.loc[name,genero]:
            return True
    return False

df.loc[df.name.map( lambda x: tiene_generos(x,["drama","game"]))]
# Out:
#        MAL_ID                                          Name  \
# 0           1                                  Cowboy Bebop
# 1           5               Cowboy Bebop: Tengoku no Tobira
# 2           6                                        Trigun
# 3           7                            Witch Hunter Robin
# 6          16                          Hachimitsu to Clover
# ...       ...                                           ...
# 17501   47257                Shinigami Bocchan to Kuro Maid
# 17518   47777  Toku: Touken Ranbu - Hanamaru - Setsugetsuka
# 17526   48177                  Ichiban Chikakute Tooi Hoshi
# 17535   48391                                  Mazica Party
# 17554   48470                              D_Cide Traumerei
#
#                                                   Genres  apariciones  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space            1
# 1                  Action, Drama, Mystery, Sci-Fi, Space            1
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen            1
# 3      Action, Mystery, Police, Supernatural, Drama, ...            1
# 6           Comedy, Drama, Josei, Romance, Slice of Life            1
# ...                                                  ...          ...
# 17501                             Comedy, Drama, Romance            1
# 17518  Action, Slice of Life, Comedy, Historical, Dra...            1
# 17526                                       Music, Drama            1
# 17535                               Game, Magic, Fantasy            1
# 17554           Action, Adventure, Drama, Magic, Fantasy            1
#
#        invalido                                            generos  \
# 0         False  [action, adventure, comedy, drama, sci-fi, space]
# 1         False            [action, drama, mystery, sci-fi, space]
# 2         False  [action, sci-fi, adventure, comedy, drama, sho...
# 3         False  [action, mystery, police, supernatural, drama,...
# 6         False     [comedy, drama, josei, romance, slice of life]
# ...         ...                                                ...
# 17501     False                           [comedy, drama, romance]
# 17518     False  [action, slice of life, comedy, historical, dr...
# 17526     False                                     [music, drama]
# 17535     False                             [game, magic, fantasy]
# 17554     False         [action, adventure, drama, magic, fantasy]
#
#                                                name
# 0                                      cowboy bebop
# 1                   cowboy bebop: tengoku no tobira
# 2                                            trigun
# 3                                witch hunter robin
# 6                              hachimitsu to clover
# ...                                             ...
# 17501                shinigami bocchan to kuro maid
# 17518  toku: touken ranbu - hanamaru - setsugetsuka
# 17526                  ichiban chikakute tooi hoshi
# 17535                                  mazica party
# 17554                              d_cide traumerei
#
# [2978 rows x 7 columns]

# %%
def tiene_generos_apply(fila,generos): 
    for genero in generos:
        if serie_genero.loc[fila["name"],genero]:
            return True
    return False

df.loc[df.apply(lambda x:tiene_generos_apply(x,["drama","game"]),axis=1)]
# Out:
#        MAL_ID                                          Name  \
# 0           1                                  Cowboy Bebop
# 1           5               Cowboy Bebop: Tengoku no Tobira
# 2           6                                        Trigun
# 3           7                            Witch Hunter Robin
# 6          16                          Hachimitsu to Clover
# ...       ...                                           ...
# 17501   47257                Shinigami Bocchan to Kuro Maid
# 17518   47777  Toku: Touken Ranbu - Hanamaru - Setsugetsuka
# 17526   48177                  Ichiban Chikakute Tooi Hoshi
# 17535   48391                                  Mazica Party
# 17554   48470                              D_Cide Traumerei
#
#                                                   Genres  apariciones  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space            1
# 1                  Action, Drama, Mystery, Sci-Fi, Space            1
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen            1
# 3      Action, Mystery, Police, Supernatural, Drama, ...            1
# 6           Comedy, Drama, Josei, Romance, Slice of Life            1
# ...                                                  ...          ...
# 17501                             Comedy, Drama, Romance            1
# 17518  Action, Slice of Life, Comedy, Historical, Dra...            1
# 17526                                       Music, Drama            1
# 17535                               Game, Magic, Fantasy            1
# 17554           Action, Adventure, Drama, Magic, Fantasy            1
#
#        invalido                                            generos  \
# 0         False  [action, adventure, comedy, drama, sci-fi, space]
# 1         False            [action, drama, mystery, sci-fi, space]
# 2         False  [action, sci-fi, adventure, comedy, drama, sho...
# 3         False  [action, mystery, police, supernatural, drama,...
# 6         False     [comedy, drama, josei, romance, slice of life]
# ...         ...                                                ...
# 17501     False                           [comedy, drama, romance]
# 17518     False  [action, slice of life, comedy, historical, dr...
# 17526     False                                     [music, drama]
# 17535     False                             [game, magic, fantasy]
# 17554     False         [action, adventure, drama, magic, fantasy]
#
#                                                name
# 0                                      cowboy bebop
# 1                   cowboy bebop: tengoku no tobira
# 2                                            trigun
# 3                                witch hunter robin
# 6                              hachimitsu to clover
# ...                                             ...
# 17501                shinigami bocchan to kuro maid
# 17518  toku: touken ranbu - hanamaru - setsugetsuka
# 17526                  ichiban chikakute tooi hoshi
# 17535                                  mazica party
# 17554                              d_cide traumerei
#
# [2978 rows x 7 columns]

# %% [markdown]
# Tambien puedo reescribir la funcion para en vez de utilizar map o apply, operar directamente entre columnas. Es claramente mas complicado de pensar en este formato, pero es posible:

# %%
def tiene_generos_cols(generos):
    result = serie_genero[generos[0]]

    for x in generos[1:]:
        result = result | serie_genero[x] 
    
    return result

def filtrar():
    result = tiene_generos_cols(["drama","game"]).to_frame().reset_index()
    result.columns = ["name","tiene"]
    tmp = pd.concat([df.reset_index(),result],axis=1) 
    return tmp[tmp.tiene]

filtrar()
# Out:
#        index  MAL_ID                            Name  \
# 3          3       7              Witch Hunter Robin
# 4          4       8                  Bouken Ou Beet
# 6          6      16            Hachimitsu to Clover
# 8          8      18          Initial D Fourth Stage
# 15        15      25                       Sunabouzu
# ...      ...     ...                             ...
# 17540  17547   48426  Kitarou Tanjou: Gegege no Nazo
# 17541  17548   48427         The Sun, Moon and Stars
# 17546  17553   48466                   Kyoukai Senki
# 17547  17554   48470                D_Cide Traumerei
# 17551  17558   48483                    Mieruko-chan
#
#                                                   Genres  apariciones  \
# 3      Action, Mystery, Police, Supernatural, Drama, ...            1
# 4              Adventure, Fantasy, Shounen, Supernatural            1
# 6           Comedy, Drama, Josei, Romance, Slice of Life            1
# 8                    Action, Cars, Sports, Drama, Seinen            1
# 15     Action, Adventure, Comedy, Ecchi, Sci-Fi, Shounen            1
# ...                                                  ...          ...
# 17540              Comedy, Demons, Supernatural, Shounen            1
# 17541                                              Music            1
# 17546                                      Action, Mecha            1
# 17547           Action, Adventure, Drama, Magic, Fantasy            1
# 17551                       Comedy, Horror, Supernatural            1
#
#        invalido                                            generos  \
# 3         False  [action, mystery, police, supernatural, drama,...
# 4         False        [adventure, fantasy, shounen, supernatural]
# 6         False     [comedy, drama, josei, romance, slice of life]
# 8         False              [action, cars, sports, drama, seinen]
# 15        False  [action, adventure, comedy, ecchi, sci-fi, sho...
# ...         ...                                                ...
# 17540     False            [comedy, demons, supernatural, shounen]
# 17541     False                                            [music]
# 17546     False                                    [action, mecha]
# 17547     False         [action, adventure, drama, magic, fantasy]
# 17551     False                     [comedy, horror, supernatural]
#
#                                                     name  tiene
# 3                               "bungaku shoujo" memoire   True
# 4                                 "bungaku shoujo" movie   True
# 6                                                 "eiji"   True
# 8                                         "eiyuu" kaitai   True
# 15     "uchuu senkan yamato" to iu jidai: seireki 220...   True
# ...                                                  ...    ...
# 17540         zukkoke sannin-gumi no jitensha kyoushitsu   True
# 17541               zukkoke sannin-gumi no koutsuu anzen   True
# 17546                                    zuori qing kong   True
# 17547                              zuori qing kong pilot   True
# 17551                                   zutto suki datta   True
#
# [2978 rows x 9 columns]

# %%
# %timeit df.loc[df.name.map( lambda x: tiene_generos(x,["drama","game"]))]
# Out:
# 228 ms ± 6.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit df.loc[df.apply(lambda x:tiene_generos_apply(x,["drama","game"]),axis=1)]
# Out:
# 472 ms ± 111 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit filtrar()
# Out:
# 4.97 ms ± 222 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Si comparamos los tiempos de ejecucion, por mas que es complicado y se hacen varias cosas entre medio, las versiones que no recurren a apply son mucho mas eficiente en terminos de tiempo.
