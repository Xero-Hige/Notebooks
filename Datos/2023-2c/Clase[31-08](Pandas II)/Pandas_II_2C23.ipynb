# %% [markdown]
# Descargo el dataset utilizando wget

# %%
# !wget "https://raw.githubusercontent.com/Xero-Hige/Notebooks/master/Datos/2023-1C/Clase%5B23-03%5D(Pandas%20II)/anime.csv"
# Out:
# --2023-08-31 18:11:47--  https://raw.githubusercontent.com/Xero-Hige/Notebooks/master/Datos/2023-1C/Clase%5B23-03%5D(Pandas%20II)/anime.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5662362 (5.4M) [text/plain]
# Saving to: ‘anime.csv’
#
# anime.csv           100%[===================>]   5.40M  --.-KB/s    in 0.09s
#
# 2023-08-31 18:11:47 (62.2 MB/s) - ‘anime.csv’ saved [5662362/5662362]

# %% [markdown]
# Importo pandas y numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Vamos a cargar un dataframe desde el csv que descargamos

# %%
df = pd.read_csv("anime.csv")

# %% [markdown]
# Reviso cuales son las columnas que tiene mi dataset

# %%
df.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#        'Type', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
#        'Studios', 'Source', 'Duration', 'Rating', 'Ranked', 'Popularity',
#        'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped',
#        'Plan to Watch', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
#        'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1'],
#       dtype='object')

# %% [markdown]
# Quiero saber cual es el genero de anime que mas series tiene, implicando que tiene mas porque es mas popular. Con lo que veo en las columnas, puedo hacer eso. Entonces:
#
# * Agrupo todo por genero
# * Le aplico una agregacion para contar los elementos no nulos. Elijo la columna del ID, si el ID es nulo no deberia existir la serie
# * Obtengo el maximo | Id del maximo
# * Hago un filtro con la serie de la columna de numero de series, para quedarme solo con aquellas que tienen una cantidad igual al numero maximo

# %%
agrupado = df.groupby("Genres")
agregado = agrupado.agg({"MAL_ID":["count"]})
agregado.columns = ["numero_series"]
maximo = agregado.numero_series.idxmax()
print(maximo)

maxima_cantidad = agregado.numero_series.max()
agregado[ agregado.numero_series >= maxima_cantidad ]
# Out:
# Hentai
#         numero_series
# Genres
# Hentai            969

# %% [markdown]
# Acepto como una realidad que el entretenimiento para adultos es el genero que mas series produce y me recibo de inutil. SIEMPRE antes de hacer nada **revisar los datos**
#
# Algunas cosas basicas:
# * Revisar los primero valores

# %%
df.head(10)
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
# 5      15                     Eyeshield 21  7.95
# 6      16             Hachimitsu to Clover  8.06
# 7      17       Hungry Heart: Wild Striker  7.59
# 8      18           Initial D Fourth Stage  8.15
# 9      19                          Monster  8.76
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# ...

# %% [markdown]
# Claramente la columna de generos no tiene solo uno, por eso nos dio el resultado que nos dio. Ya vemos que lo mas simple nos puede salvar de mucho.
#
# * Pedirle a pandas que nos describa el dataframe

# %%
df.describe()
# Out:
#              MAL_ID    Popularity       Members      Favorites       Watching  \
# count  17562.000000  17562.000000  1.756200e+04   17562.000000   17562.000000
# mean   21477.192347   8763.452340  3.465854e+04     457.746270    2231.487758
# std    14900.093170   5059.327278  1.252821e+05    4063.473313   14046.688133
# min        1.000000      0.000000  1.000000e+00       0.000000       0.000000
# 25%     5953.500000   4383.500000  3.360000e+02       0.000000      13.000000
# 50%    22820.000000   8762.500000  2.065000e+03       3.000000      73.000000
# 75%    35624.750000  13145.000000  1.322325e+04      31.000000     522.000000
# max    48492.000000  17565.000000  2.589552e+06  183914.000000  887333.000000
#
#           Completed        On-Hold        Dropped  Plan to Watch
# count  1.756200e+04   17562.000000   17562.000000   17562.000000
# mean   2.209557e+04     955.049653    1176.599533    8199.831227
# std    9.100919e+04    4275.675096    4740.348653   23777.691963
# ...

# %% [markdown]
# * Ver cuales son los valores de las columnas que queremos analizar

# %%
df.Genres.unique()
# Out:
# array(['Action, Adventure, Comedy, Drama, Sci-Fi, Space',
#        'Action, Drama, Mystery, Sci-Fi, Space',
#        'Action, Sci-Fi, Adventure, Comedy, Drama, Shounen', ...,
#        'Horror, Demons, Supernatural, Thriller', 'Sci-Fi, Space, Vampire',
#        'Adventure, Mystery, Supernatural'], dtype=object)

# %% [markdown]
# Podemos mejorar el analisis modificando los generos para que tenga algo que si podamos contar. Por ejemplo, quedemosnos con el primer genero que aparece listado:

# %%
df.Genres.unique()[0]
# Out:
# 'Action, Adventure, Comedy, Drama, Sci-Fi, Space'

# %%
df.Genres.unique()[0].split(",")
# Out:
# ['Action', ' Adventure', ' Comedy', ' Drama', ' Sci-Fi', ' Space']

# %%
df.Genres.map( lambda x: x.split(",")[0])
# Out:
# 0           Action
# 1           Action
# 2           Action
# 3           Action
# 4        Adventure
#            ...
# 17557    Adventure
# 17558       Comedy
# 17559      Mystery
# 17560    Adventure
# 17561       Action
# Name: Genres, Length: 17562, dtype: object

# %% [markdown]
# El lambda es equivalente a

# %%
def modificar(cadena):
    elementos = cadena.split(",")
    principal = elementos[0]
    return principal

df.Genres = df.Genres.map(modificar)
df.Genres
# Out:
# 0           Action
# 1           Action
# 2           Action
# 3           Action
# 4        Adventure
#            ...
# 17557    Adventure
# 17558       Comedy
# 17559      Mystery
# 17560    Adventure
# 17561       Action
# Name: Genres, Length: 17562, dtype: object

# %% [markdown]
# Si volvemos a revisar, ahora tenemos valores mas manejables

# %%
df.Genres.unique()
# Out:
# array(['Action', 'Adventure', 'Comedy', 'Slice of Life', 'Drama',
#        'Sci-Fi', 'Samurai', 'Game', 'Harem', 'Military', 'Space', 'Music',
#        'Mecha', 'Supernatural', 'Historical', 'Mystery', 'School',
#        'Hentai', 'Fantasy', 'Ecchi', 'Horror', 'Kids', 'Sports',
#        'Dementia', 'Magic', 'Romance', 'Police', 'Psychological', 'Cars',
#        'Shounen', 'Demons', 'Parody', 'Shoujo', 'Super Power', 'Vampire',
#        'Martial Arts', 'Seinen', 'Yaoi', 'Thriller', 'Josei', 'Unknown',
#        'Shounen Ai'], dtype=object)

# %% [markdown]
# Si vuelvo a aplicar lo mismo que antes

# %%
agrupado = df.groupby("Genres")
agregado = agrupado.agg({"MAL_ID":["count"]})
agregado.columns = ["numero_series"]
maximo = agregado.numero_series.idxmax()
print(maximo)
# Out:
# Action

# %% [markdown]
# Ahora el resultado cambia a algo mas esperable, aunque sigue estando mal.

# %%
agregado
# Out:
#                numero_series
# Genres
# Action                  3888
# Adventure               1480
# Cars                      62
# Comedy                  3120
# Dementia                 382
# Demons                    71
# Drama                    800
# Ecchi                    130
# Fantasy                  518
# Game                     183
# Harem                    146
# Hentai                  1165
# Historical               261
# Horror                    83
# Josei                      3
# Kids                    1081
# Magic                    108
# Martial Arts               9
# Mecha                     84
# Military                 105
# Music                   1453
# Mystery                  194
# Parody                    75
# Police                    13
# Psychological             48
# Romance                  148
# Samurai                    9
# School                    49
# Sci-Fi                   535
# Seinen                    10
# ...

# %%
df
# Out:
#        MAL_ID                             Name    Score     Genres  \
# 0           1                     Cowboy Bebop     8.78     Action
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39     Action
# 2           6                           Trigun     8.24     Action
# 3           7               Witch Hunter Robin     7.27     Action
# 4           8                   Bouken Ou Beet     6.98  Adventure
# ...       ...                              ...      ...        ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown  Adventure
# 17558   48483                     Mieruko-chan  Unknown     Comedy
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown    Mystery
# 17560   48491      Yama no Susume: Next Summit  Unknown  Adventure
# 17561   48492                    Scarlet Nexus  Unknown     Action
#
#                           English name                     Japanese name  \
# 0                         Cowboy Bebop                         カウボーイビバップ
# ...

# %% [markdown]
# Como esta modificado, ahora tengo que recargar todo el dataset. Aprovecho y me quedo con unicamente las columnas que me importan

# %%
df = pd.read_csv("anime.csv")
df2 = df[["MAL_ID","Name","Genres"]]

# %% [markdown]
# # Transformando los generos de forma correcta
#
# Par poder separar los generos de cada serie, necesito:
# * Primero pasar la cadena a una lista
# * Despues, tengo que procesar los generos para eliminar los espacios a los costados y las mayusculas,(para evitar que un genero se separe en multiples)
#
# Podemos hacer todo esto a la vez con un map y una funcion lambda como antes:

# %%
df2.Genres.map(lambda x: [ string.strip().lower() for string in x.split(",")])
# Out:
# 0        [action, adventure, comedy, drama, sci-fi, space]
# 1                  [action, drama, mystery, sci-fi, space]
# 2        [action, sci-fi, adventure, comedy, drama, sho...
# 3        [action, mystery, police, supernatural, drama,...
# 4              [adventure, fantasy, shounen, supernatural]
#                                ...
# 17557                   [adventure, mystery, supernatural]
# 17558                       [comedy, horror, supernatural]
# 17559    [mystery, dementia, horror, psychological, sup...
# 17560                   [adventure, slice of life, comedy]
# 17561                                    [action, fantasy]
# Name: Genres, Length: 17562, dtype: object

# %%
def limpiar_lista(lista):
    separado = lista.split(",")
    resultado = []
    for x in separado:
        procesado = x.strip().lower()
        resultado.append(procesado)

    return resultado

df2.Genres.map(limpiar_lista)
# Out:
# 0        [action, adventure, comedy, drama, sci-fi, space]
# 1                  [action, drama, mystery, sci-fi, space]
# 2        [action, sci-fi, adventure, comedy, drama, sho...
# 3        [action, mystery, police, supernatural, drama,...
# 4              [adventure, fantasy, shounen, supernatural]
#                                ...
# 17557                   [adventure, mystery, supernatural]
# 17558                       [comedy, horror, supernatural]
# 17559    [mystery, dementia, horror, psychological, sup...
# 17560                   [adventure, slice of life, comedy]
# 17561                                    [action, fantasy]
# Name: Genres, Length: 17562, dtype: object

# %% [markdown]
# El resultado de aplicarle .map a una serie, es otra serie. En este caso la serie es una serie de 'objects' porque es una columna de listas.
#
# En este caso, vamos a crear una nueva columna en nuestro dataframe con los datos de la serie creada. En este caso hacemos una nueva columna para tener como referencia los datos originales, pero bien se podria sobreescribir la columna original para optimizar el uso de espacio. Siempre que se vaya a agregar una columna hay que utilizar [] (se puede utilizar . pero esta fuertemente desaconsejado).

# %%
df2["generos_limpios"] = df2.Genres.map(limpiar_lista)
df2
# Out:
# <ipython-input-45-91fe27972af8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["generos_limpios"] = df2.Genres.map(limpiar_lista)
#        MAL_ID                             Name  \
# 0           1                     Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira
# 2           6                           Trigun
# 3           7               Witch Hunter Robin
# 4           8                   Bouken Ou Beet
# ...       ...                              ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu
# 17558   48483                     Mieruko-chan
# 17559   48488  Higurashi no Naku Koro ni Sotsu
# 17560   48491      Yama no Susume: Next Summit
# 17561   48492                    Scarlet Nexus
#
# ...

# %% [markdown]
# Con los datos en una lista, ahora puedo aplicar explode para que cada valor se vuelva una fila y se una a los datos anteriores

# %%
explotado = df2.explode("generos_limpios")
explotado
# Out:
#        MAL_ID                         Name  \
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# 0           1                 Cowboy Bebop
# ...       ...                          ...
# 17560   48491  Yama no Susume: Next Summit
# 17560   48491  Yama no Susume: Next Summit
# 17560   48491  Yama no Susume: Next Summit
# 17561   48492                Scarlet Nexus
# 17561   48492                Scarlet Nexus
#
#                                                 Genres generos_limpios
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space          action
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space       adventure
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space          comedy
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space           drama
# 0      Action, Adventure, Comedy, Drama, Sci-Fi, Space          sci-fi
# ...

# %% [markdown]
# Ya que dejamos los nombres, podemos utilizarlos para indexar nuestro dataframe y asi poder revisar datos que conozcamos y poder validar lo que hicimos

# %%
explotado.set_index("Name").loc["Fullmetal Alchemist"]
# Out:
#                      MAL_ID  \
# Name
# Fullmetal Alchemist     121
# Fullmetal Alchemist     121
# Fullmetal Alchemist     121
# Fullmetal Alchemist     121
# Fullmetal Alchemist     121
# Fullmetal Alchemist     121
# Fullmetal Alchemist     121
# Fullmetal Alchemist     121
#
#                                                                 Genres  \
# Name
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
# Fullmetal Alchemist  Action, Adventure, Comedy, Drama, Fantasy, Mag...
#
#                     generos_limpios
# Name
# ...

# %% [markdown]
# Ya que estoy, voyua normalizar los nombres para evitar problemas mas adelante

# %%
explotado["name"] = explotado.Name.map(lambda x:x.lower())
explotado.head(20)
# Out:
#    MAL_ID                             Name  \
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 0       1                     Cowboy Bebop
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 2       6                           Trigun
# 3       7               Witch Hunter Robin
# 3       7               Witch Hunter Robin
# 3       7               Witch Hunter Robin
#
# ...

# %% [markdown]
# # Pivots
# ❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗
#
# Nota al lector: Podria hacer un groupby generos y despues hacer un count unique para obtener el resultado que buscaba originalmente... pero no porque sino aca terminaria el notebook y no quiero buscar otro dataset con las propiedades de este, asi que seguime la corriente. Siempre podes como ejercicio cargar en un notebook nuevo el dataset e intentar llegar al resultado por ese camino.
# ❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗
#
# Vamos a cambiar nuestros datos a otro formato, una matiz donde para cada serie, tenemos una columna que indica si es o no de determinado genero. Con eso, simplemente al contar cada columna, podria ver cual tiene mas.
#
# Para eso vamos a utilizar pivot porque cada serie solo deberia aparecer una unica vez asociada a un genero. Elegimos la columna de MAL_ID como valores porque en este caso es lo mismo, o tiene un valor (la serie es de ese genero) o es un nan (la serie no es de ese genero)

# %%
explotado.pivot("name","generos_limpios","MAL_ID")
# Out:
# <ipython-input-51-9e513939f11a>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   explotado.pivot("name","generos_limpios","MAL_ID")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-9e513939f11a> in <cell line: 1>()
# ----> 1 explotado.pivot("name","generos_limpios","MAL_ID")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    8565         from pandas.core.reshape.pivot import pivot
#    8566
# ...

# %% [markdown]
# Pivot falla porque dice tener valores repetidos. Esto significa que existe al menos un par nombre,genero que aparece mas de una vez. Por precondicion no deberia ocurrir, porque las series no deberian repetirse y los generos que extrajimos son unicos. Este tipo de cosas nos hablan de que hay errores en el dataset (y nos demuestran que no se puede confiar ciegamente en nada), repito, **SIEMPRE HAY QUE REVISAR LOS DATOS, ES PARTE FUNDAMENTAL DEL PROCESO**

# %%
df_count = explotado.pivot_table(index="name",columns="generos_limpios",values="MAL_ID",aggfunc="count")
df_count
# Out:
# generos_limpios                                     action  adventure  cars  \
# name
# "0"                                                    NaN        NaN   NaN
# "aesop" no ohanashi yori: ushi to kaeru, yokuba...     NaN        NaN   NaN
# "bungaku shoujo" kyou no oyatsu: hatsukoi              NaN        NaN   NaN
# "bungaku shoujo" memoire                               NaN        NaN   NaN
# "bungaku shoujo" movie                                 NaN        NaN   NaN
# ...                                                    ...        ...   ...
# zutto mae kara suki deshita.: kokuhaku jikkou i...     NaN        NaN   NaN
# zutto suki datta                                       NaN        NaN   NaN
# üks uks                                                NaN        NaN   NaN
# ēldlive                                                1.0        NaN   NaN
# ◯                                                      NaN        NaN   NaN
#
# ...

# %% [markdown]
# Este dataframe nuevo, ahora tiene 1 si la serie esta asociada a un genero, o NaN en caso contrario. O eso seria lo esperable, pero ya sabemos de antemano que hay almenos algo que no es ni NaN ni 1. Podemos probar obteniendo el maximo por columna:

# %%
df_count.max()
# Out:
# generos_limpios
# action           2.0
# adventure        1.0
# cars             1.0
# comedy           1.0
# dementia         1.0
# demons           2.0
# drama            1.0
# ecchi            1.0
# fantasy          3.0
# game             1.0
# harem            1.0
# hentai           1.0
# historical       1.0
# horror           1.0
# josei            1.0
# kids             2.0
# magic            3.0
# martial arts     1.0
# mecha            1.0
# military         1.0
# music            1.0
# mystery          1.0
# parody           1.0
# police           1.0
# psychological    1.0
# romance          1.0
# samurai          1.0
# school           3.0
# sci-fi           1.0
# seinen           1.0
# shoujo           1.0
# shoujo ai        1.0
# shounen          1.0
# shounen ai       1.0
# slice of life    1.0
# space            1.0
# sports           1.0
# super power      1.0
# supernatural     1.0
# thriller         1.0
# unknown          1.0
# vampire          1.0
# ...

# %%
df_count.loc[df_count["action"] > 1]
# Out:
# generos_limpios                                     action  adventure  cars  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...     2.0        NaN   NaN
#
# generos_limpios                                     comedy  dementia  demons  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...     NaN       NaN     2.0
#
# generos_limpios                                     drama  ecchi  fantasy  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...    NaN    NaN      3.0
#
# generos_limpios                                     game  ...  slice of life  \
# name                                                      ...
# maou gakuin no futekigousha: shijou saikyou no ...   NaN  ...            NaN
#
# generos_limpios                                     space  sports  \
# name
# maou gakuin no futekigousha: shijou saikyou no ...    NaN     NaN
#
# generos_limpios                                     super power  supernatural  \
# name
# ...

# %% [markdown]
# Si revisamos en el 'explotado', vemos que la serie aparece multiples veces, pero algunos de esos datos son inconsistentes. Esto nos puede llevar a pensar que el dataset esta mal, ya que no podemos con la informacion que tenemos saber el por que de los datos duplicados
#
# Notar que si no me hubiera querido ahorrar un paso unos frames mas arriba, ahora no tendria que volver a setear el indice.

# %%
explotado.set_index("Name").loc["Maou Gakuin no Futekigousha: Shijou Saikyou no Maou no Shiso, Tensei shite Shison-tachi no Gakkou e"]
# Out:
#                                                     MAL_ID  \
# Name
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   40496
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   40496
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   40496
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   40496
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   40496
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48417
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48417
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48417
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48418
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48418
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48418
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48418
# Maou Gakuin no Futekigousha: Shijou Saikyou no ...   48418
#
#                                                                                     Genres  \
# Name
# ...

# %%
df.groupby("Name").agg({"MAL_ID":"count"})
# Out:
#                                                     MAL_ID
# Name
# "0"                                                      1
# "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokuba...       1
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                1
# "Bungaku Shoujo" Memoire                                 1
# "Bungaku Shoujo" Movie                                   1
# ...                                                    ...
# xxxHOLiC Rou                                             1
# xxxHOLiC Shunmuki                                        1
# Üks Uks                                                  1
# ēlDLIVE                                                  1
# ◯                                                        1
#
# [17558 rows x 1 columns]

# %%
df["apariciones"] = df.groupby("Name").transform("count")["MAL_ID"]

# %% [markdown]
# Si eliminamos todos los invalidos, ahora podemos volver a hacer lo que hicimos al principio para llegar a aplicar pivot. En este caso no tengo forma de saber por que estan mas de una vez, y como no se como subsanar eso, descarto esos datos.
#
# Aplicando la misma logica que antes, me hago una nueva columna con el valor que me diga si es un dato valido o no (hago una nueva columna, porque quiza mas adelante me sirve eso para otra cosa.

# %%
df["invalido"] = df.apariciones > 1
df2 = df[~df.invalido]
df2
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df2["generos_limpios"] = df2.Genres.map(limpiar_lista)
explotado = df2.explode("generos_limpios")
explotado.pivot("Name","generos_limpios","MAL_ID")
# Out:
# <ipython-input-62-8203a11d1657>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["generos_limpios"] = df2.Genres.map(limpiar_lista)
# <ipython-input-62-8203a11d1657>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   explotado.pivot("Name","generos_limpios","MAL_ID")
# generos_limpios                                      action  adventure  cars  \
# Name
# "0"                                                     NaN        NaN   NaN
# "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokuba...      NaN        NaN   NaN
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi               NaN        NaN   NaN
# "Bungaku Shoujo" Memoire                                NaN        NaN   NaN
# ...

# %% [markdown]
# Ahora si, antes de hacer el pivot vamos a pensar mejor que es lo que queremos obtener. Estamos buscando llegar a un DataFrame que para cada serie, tenga para cada uno de los generos si pertenece a ese o no. Como lo que vamos a querer que aparezca en mi nuevo DataFrame son valores booleanos, y sabiendo que en expandido estan todos los pares serie-genero que son validos; puedo agregar una columna solo con True para que al generar el pivot me queden los valores True en los pares validos.
#
# De la misma forma, sabemos que si en expandido no aparece un determinado par serie-genero, el mismo es implicitamente False, entonces al pivot le puedo hacer un fillna por ese valor

# %%
explotado["t"] = True
serie_genero = explotado.pivot("Name","generos_limpios","t")
serie_genero = serie_genero.fillna(False)
serie_genero
# Out:
# <ipython-input-67-195568791e20>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   serie_genero = explotado.pivot("Name","generos_limpios","t")
# generos_limpios                                     action  adventure   cars  \
# Name
# "0"                                                  False      False  False
# "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokuba...   False      False  False
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi            False      False  False
# "Bungaku Shoujo" Memoire                             False      False  False
# "Bungaku Shoujo" Movie                               False      False  False
# ...                                                    ...        ...    ...
# xxxHOLiC Rou                                         False      False  False
# xxxHOLiC Shunmuki                                    False      False  False
# ...

# %% [markdown]
# Si genero la suma de cada columna y ordeno los valores, puedo encontrar lo que buscaba originalmente

# %%
serie_genero.sum().sort_values()
# Out:
# generos_limpios
# yuri               32
# yaoi               42
# unknown            63
# shoujo ai          79
# josei              97
# shounen ai        100
# thriller          131
# cars              133
# vampire           136
# samurai           202
# police            247
# psychological     345
# game              386
# harem             399
# martial arts      425
# horror            462
# space             495
# demons            499
# dementia          512
# military          576
# super power       632
# parody            660
# shoujo            688
# sports            713
# mystery           727
# ecchi             767
# seinen            829
# magic            1078
# mecha            1101
# historical       1143
# hentai           1348
# supernatural     1478
# school           1639
# romance          1899
# slice of life    1913
# shounen          2003
# music            2244
# sci-fi           2582
# drama            2619
# kids             2662
# ...

# %% [markdown]
# De yapa, podemos acceder a la informacion haciendo esto

# %%
serie_genero.loc["xxxHOLiC Rou","game"]
# Out:
# False

# %%
serie_genero.loc["xxxHOLiC Rou","supernatural"]
# Out:
# True

# %% [markdown]
# Lo que despues me dejaria por ej armar un filtro

# %%
serie_genero["game"] & serie_genero["supernatural"]
# Out:
# Name
# "0"                                                       False
# "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokubatta Inu    False
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                 False
# "Bungaku Shoujo" Memoire                                  False
# "Bungaku Shoujo" Movie                                    False
#                                                           ...
# xxxHOLiC Rou                                              False
# xxxHOLiC Shunmuki                                         False
# Üks Uks                                                   False
# ēlDLIVE                                                   False
# ◯                                                         False
# Length: 17555, dtype: bool

# %%
serie_genero.loc["xxxHOLiC Rou","game"] & serie_genero.loc["xxxHOLiC Rou","supernatural"]
# Out:
# False

# %%
serie_genero.loc[serie,gen_1] & serie_genero.loc[serie,gen_2]
