// %% [markdown]
// # Clase Procesos

// %% [markdown]
// #### Ejercicio:
//
// Escribir un programa que reciba a través de la línea de comandos la cantidad de procesos hijos que debe crear.
//  * Cada proceso hijo debe dormir un numero aleatorio de segundos comprendido entre 0 y 30.
//  * El proceso padre debe esperar la terminación de cada uno de sus hijos.
//  * A medida que los hijos van terminando:
//   * El padre presentará en pantalla el pid de cada uno de ellos
//   * La cantidad de segundos que ha estado durmiendo cada hijo.

// %%
#include <stdio.h>
#include <unistd.h>
#include <sys/wait.h>
#include <stdlib.h>

#define NUMBER_OF_CHILDS 3
#define WAIT_TIME 10

long int rndom() {
    srand(getpid());
    long int result = rand() % WAIT_TIME;
    return result;
}

int main() {
    setbuf(stdout, NULL); //Disable stdout buffer

    int childs = NUMBER_OF_CHILDS;
    printf("Spawning %d process\n" , childs);
    
    for (int i = 0; i < childs; i++) {
        int pid = fork();

        if (pid == 0) {
            printf("Started process with id: %d\n" , getpid());
            unsigned int s = rndom();
            sleep(s);
            printf("Exited %d after -> %d\n",getpid(),s);
            exit(s);
        }

    }

    for (int i = 0; i < childs; i++) {
        unsigned int a;
        wait(&a);
        printf("Kiled %d after %d (%d)\n",i + 1,a,WEXITSTATUS(a));
    }

    return 0;
}
// Out:
// Spawning 3 process
// Started process with id: 132
// Started process with id: 133
// Started process with id: 134
// Exited 134 after -> 1
// Kiled 1 after 256 (1)
// Exited 132 after -> 4
// Kiled 2 after 1024 (4)
// Exited 133 after -> 5
// Kiled 3 after 1280 (5)

// %%
#include <stdio.h>
#include <unistd.h>
#include <sys/wait.h>
#include <stdlib.h>

#define NUMBER_OF_CHILDS 10
#define WAIT_TIME 3

long int rndom() {
    srand(getpid());
    long int result = rand() % WAIT_TIME;
    return result;
}

int main() {
    setbuf(stdout, NULL); //Disable stdout buffer

    int childs = NUMBER_OF_CHILDS;
    printf("Spawning %d process\n" , childs);
    
    for (int i = 0; i < childs; i++) {
        int pid = fork();

        if (pid == 0) {
            printf("Started process with id: %d\n" , getpid());
            unsigned int s = rndom();
            sleep(s);
            printf("Exited %d after -> %d\n",getpid(),s);
            exit(s);
        }

    }

    for (int i = 0; i < childs; i++) {
        unsigned int a;
        wait(&a);
        printf("Kiled %d after %d (%d)\n",i + 1,a,WEXITSTATUS(a));
    }

    return 0;
}
// Out:
// Spawning 10 process
// Started process with id: 141
// Started process with id: 142
// Started process with id: 144
// Started process with id: 143
// Started process with id: 146
// Exited 143 after -> 0
// Started process with id: 145
// Started process with id: 147
// Exited 145 after -> 0
// Kiled 1 after 0 (0)
// Kiled 2 after 0 (0)
// Started process with id: 149
// Started process with id: 148
// Started process with id: 150
// Exited 150 after -> 0
// Exited 149 after -> 0
// Kiled 3 after 0 (0)
// Kiled 4 after 0 (0)
// Exited 141 after -> 1
// Kiled 5 after 256 (1)
// Exited 147 after -> 1
// Kiled 6 after 256 (1)
// Exited 148 after -> 1
// Kiled 7 after 256 (1)
// Exited 142 after -> 2
// Exited 144 after -> 2
// Exited 146 after -> 2
// Kiled 8 after 512 (2)
// Kiled 9 after 512 (2)
// Kiled 10 after 512 (2)

// %%
#include <stdio.h>
#include <unistd.h>
#include <sys/wait.h>
#include <stdlib.h>

#define NUMBER_OF_CHILDS 3
#define WAIT_TIME 10

long int rndom() {
    srand(getpid());
    long int result = rand() % WAIT_TIME;
    return result;
}

int main() {
    setbuf(stdout, NULL); //Disable stdout buffer

    int childs = NUMBER_OF_CHILDS;
    printf("Spawning %d process\n" , childs);
    
    for (int i = 0; i < childs; i++) {
        int pid = fork();

        if (pid == 0) {
            printf("Started process with id: %d\n" , getpid());
            unsigned int s = rndom();
            sleep(s);
            printf("Exited %d after -> %d\n",getpid(),s);
            exit(s);
        }

    }

    for (int i = 0; i < childs; i++) {
        unsigned int a;
        wait(&a);
        printf("Kiled %d after %d (%d)\n",i + 1,a,WEXITSTATUS(a));
    }

    return 0;
}
// Out:
// Spawning 3 process
// Started process with id: 158
// Started process with id: 157
// Started process with id: 159
// Exited 157 after -> 3
// Kiled 1 after 768 (3)
// Exited 158 after -> 5
// Kiled 2 after 1280 (5)
// Exited 159 after -> 8
// Kiled 3 after 2048 (8)

// %%
#include <stdio.h>
#include <unistd.h>
#include <sys/wait.h>
#include <stdlib.h>

#define NUMBER_OF_CHILDS 10
#define WAIT_TIME 10

long int rndom() {
    srand(getpid());
    long int result = rand() % WAIT_TIME;
    return result;
}

int main() {
    setbuf(stdout, NULL); //Disable stdout buffer

    int childs = NUMBER_OF_CHILDS;
    printf("Spawning %d process\n" , childs);
    
    for (int i = 0; i < childs; i++) {
        int pid = fork();

        if (pid == 0) {
            printf("Started process with id: %d\n" , getpid());
            unsigned int s = rndom();
            sleep(s);
            printf("Exited %d after -> %d\n",getpid(),s);
            exit(s);
        }

    }

    for (int i = 0; i < childs; i++) {
        unsigned int a;
        wait(&a);
        printf("Kiled %d after %d (%d)\n",i + 1,a,WEXITSTATUS(a));
    }

    return 0;
}
// Out:
// Spawning 10 process
// Started process with id: 166
// Started process with id: 168
// Started process with id: 169
// Started process with id: 170
// Started process with id: 167
// Started process with id: 171
// Started process with id: 172
// Started process with id: 175
// Started process with id: 173
// Started process with id: 174
// Exited 175 after -> 0
// Kiled 1 after 0 (0)
// Exited 166 after -> 4
// Kiled 2 after 1024 (4)
// Exited 172 after -> 5
// Kiled 3 after 1280 (5)
// Exited 170 after -> 6
// Kiled 4 after 1536 (6)
// Exited 173 after -> 6
// Kiled 5 after 1536 (6)
// Exited 167 after -> 7
// Kiled 6 after 1792 (7)
// Exited 168 after -> 8
// Exited 171 after -> 8
// Kiled 7 after 2048 (8)
// Exited 174 after -> 8
// Kiled 8 after 2048 (8)
// Kiled 9 after 2048 (8)
// Exited 169 after -> 9
// Kiled 10 after 2304 (9)
